# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("2b.csv", sep=';')

# %%
df = df.drop("Unnamed: 7", axis=1)

# %%
df = df.drop("Grouping example (first 20 transactions)", axis=1)

# %%
df = df.sort_values(by=["Maturity period, days", "Rate, %"], ascending = [True, True])

# %%
df
# Out:
#       Asset (active)  Loan (passive)) Maturity date  Maturity period, days  \
# 268       10900000.0              0.0    23.04.2018                     32
# 269              0.0       26000000.0    23.04.2018                     32
# 321        5600000.0              0.0    23.04.2018                     32
# 322              0.0       11200000.0    23.04.2018                     32
# 370       30800000.0              0.0    23.04.2018                     32
# ...              ...              ...           ...                    ...
# 1890      16700000.0              0.0    21.06.2018                     91
# 1975     106000000.0              0.0    21.06.2018                     91
# 1989             0.0       30800000.0    21.06.2018                     91
# 449       21300000.0              0.0    22.06.2018                     92
# 539       18000000.0              0.0    22.06.2018                     92
#
#       Rate, %  ANSWER (GROUP NUMBER)
# 268    1.7445                    NaN
# 269    1.7445                    NaN
# 321    1.7445                    NaN
# 322    1.7445                    NaN
# 370    1.7445                    NaN
# ...       ...                    ...
# 1890   2.2225                    NaN
# 1975   2.2225                    NaN
# 1989   2.2225                    NaN
# 449    2.2481                    NaN
# 539    2.2481                    NaN
#
# [2175 rows x 6 columns]

# %%
print(df["Rate, %"].min())
print(df["Rate, %"].max())

print(df["Maturity period, days"].min())
print(df["Maturity period, days"].max())
# Out:
# 0.8495
# 9.125
# 32
# 92

# %%
gr_number = 1

# %%
for i in range(8495, 91251, 1500):  # by interest rates
    for j in range(32, 93, 30):  # by maturity period
        df.loc[(j + 30 > df["Maturity period, days"]) & (df["Maturity period, days"] >= j) & (df["Rate, %"] >= i / 10000) & (df["Rate, %"] < (i + 1500) / 10000), "ANSWER (GROUP NUMBER)"] = gr_number
        gr_number += 1

# %%
df["ANSWER (GROUP NUMBER)"].unique()
# Out:
# array([ 16.,  25.,  37.,  52.,  19.,  13.,  43.,  64.,   1.,  58.,  70.,
#        166., 109.,  10.,  22.,  55.,   7.,  40.,  23.,  26.,   5.,  44.,
#        122., 140.,  35.,   8.,  17.,  47.,  11.,   2.,  29.,  30.])

# %%
df = df.fillna(-1)

# %%
df["ANSWER (GROUP NUMBER)"] = df["ANSWER (GROUP NUMBER)"].astype(int)

# %%
rwa = 0

# %%
for val in df["ANSWER (GROUP NUMBER)"].unique():
    A = df.loc[df["ANSWER (GROUP NUMBER)"] == val, "Asset (active)"].sum()  # sum of the assets in a group
    L = df.loc[df["ANSWER (GROUP NUMBER)"] == val, "Loan (passive))"].sum()  # sum of the loans in a group
    if val != -1:
        if A != 0 and L != 0:
            rwa += abs(A - L)  # netting
            continue
        df.loc[df["ANSWER (GROUP NUMBER)"] == val, "ANSWER (GROUP NUMBER)"] = -1
    df.loc[df["ANSWER (GROUP NUMBER)"] == val, "ANSWER (GROUP NUMBER)"] = -1

# %%
A_not_netted = sum(df.loc[df["ANSWER (GROUP NUMBER)"] == -1, "Asset (active)"])  # sum of the not netted assets
L_not_netted = sum(df.loc[df["ANSWER (GROUP NUMBER)"] == -1, "Loan (passive))"])  # sum of the not netted loans

# %%
rwa += (A_not_netted + L_not_netted) * 0.1 + abs(A_not_netted - L_not_netted) * 0.4

# %%
rwa  # answer, 3521213815.1199985
# Out:
# np.float64(3521213815.1199985)

# %%
df.columns = ['asset', 'liab', 'm_d', 'm_p', 'ir', 'gn']

# %%
df.to_csv("2b_answer.csv", index=False)
